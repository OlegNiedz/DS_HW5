# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegNiedz/DS_HW5/blob/main/Hw5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)" посилання

# %%
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
tables = pd.read_html(url, thousands='.' ,na_values="—", decimal=",", index_col=0)
oryginal_table=tables[12]
table=oryginal_table.copy()
table
# Out:
#                    1950  1960  1970  1990  2000  2012  2014  2019
# Регіон
# Крим               23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# Вінницька          22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# Волинська          24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# Дніпропетровська   20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# Донецька           27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# Житомирська        26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# Закарпатська       31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# Запорізька         21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# Київська           20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# Кіровоградська     21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# Луганська          26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# Львівська          23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# ...

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
table.head()
# Out:
#                   1950  1960  1970  1990  2000  2012  2014  2019
# Регіон
# Крим              23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# Вінницька         22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# Волинська         24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# Донецька          27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
table_size = table.shape
table_size
# Out:
# (28, 8)

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
# table.replace(to_replace="—",value=np.nan,inplace=True)
table
# Out:
#                    1950  1960  1970  1990  2000  2012  2014  2019
# Регіон
# Крим               23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# Вінницька          22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# Волинська          24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# Дніпропетровська   20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# Донецька           27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# Житомирська        26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# Закарпатська       31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# Запорізька         21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# Київська           20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# Кіровоградська     21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# Луганська          26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# Львівська          23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# ...

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
table.dtypes
# Out:
# 1950    float64
# 1960    float64
# 1970    float64
# 1990    float64
# 2000    float64
# 2012    float64
# 2014    float64
# 2019    float64
# dtype: object

# %% [markdown]
# Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
table_num = table.apply(pd.to_numeric)
table_num
# Out:
#                    1950  1960  1970  1990  2000  2012  2014  2019
# Регіон
# Крим               23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# Вінницька          22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# Волинська          24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# Дніпропетровська   20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# Донецька           27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# Житомирська        26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# Закарпатська       31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# Запорізька         21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# Київська           20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# Кіровоградська     21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# Луганська          26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# Львівська          23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
count_null = table.isnull().sum()
count= table.count()
print(f'{count_null/count}' )
# Out:
# 1950    0.076923
# 1960    0.037037
# 1970    0.037037
# 1990    0.000000
# 2000    0.000000
# 2012    0.000000
# 2014    0.076923
# 2019    0.166667
# dtype: float64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
table.drop(table.index[-1])
# Out:
#                    1950  1960  1970  1990  2000  2012  2014  2019
# Регіон
# Крим               23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# Вінницька          22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# Волинська          24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# Дніпропетровська   20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# Донецька           27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# Житомирська        26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# Закарпатська       31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# Запорізька         21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# Київська           20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# Кіровоградська     21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# Луганська          26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# Львівська          23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# ...

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
table_num.fillna(table.mean(), inplace=True)
table_num
# Out:
#                         1950       1960       1970  1990  2000  2012  \
# Регіон
# Крим               23.000000  20.600000  16.000000  13.0   7.3  12.6
# Вінницька          22.400000  19.200000  14.200000  12.4   8.4  11.2
# Волинська          24.700000  25.000000  17.900000  15.3  11.2  14.8
# Дніпропетровська   20.400000  20.400000  15.100000  12.3   7.1  11.2
# Донецька           27.100000  21.400000  14.000000  10.9   6.1   9.8
# Житомирська        26.100000  22.300000  15.900000  12.9   8.9  12.2
# Закарпатська       31.400000  27.300000  20.700000  16.8  11.5  15.1
# Запорізька         21.900000  19.700000  15.000000  12.4   7.1  10.6
# Івано-Франківська  24.300000  24.800000  18.200000  15.5  10.3  12.4
# Київська           20.400000  18.900000  15.600000  12.3   7.3  12.2
# Кіровоградська     21.600000  17.100000  14.500000  12.6   7.9  11.0
# Луганська          26.200000  23.500000  14.400000  11.6   6.2   9.6
# ...

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
mid_level_2019 = table['2019'][-1]
print(table[table["2019"] > mid_level_2019]['2019'])
# Out:
# Регіон
# Волинська            10.1
# Закарпатська         10.4
# Івано-Франківська     8.8
# Львівська             8.7
# Одеська               8.8
# Рівненська           10.7
# Чернівецька           9.2
# Київ                 11.0
# Name: 2019, dtype: float64
# C:\Users\Olegn\AppData\Local\Temp\ipykernel_20624\2792708954.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mid_level_2019 = table['2019'][-1]

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
q=table[table["2014"] == table["2014"].max()]['2014']
q
# Out:
# Регіон
# Рівненська    14.8
# Name: 2014, dtype: float64

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
y='2019'
table[y].plot(kind="bar",title=f'Народжуванність в Україні у {y} році',ylabel='Коеф. народжуванності')

plt.show()

# %%
# Створення графіків
plt.figure(figsize=(12, 20))

# Графік 1: Лінійний графік
plt.subplot(3, 1, 1)
plt.plot(table_num.index, table_num['1950'], marker="o", linestyle="-")
plt.legend(table_num.columns)
plt.title("Народжуванність у 1950 році")
plt.xlabel("Регіони")
plt.ylabel("Показник")
plt.tick_params(axis="x", rotation=90)
plt.grid(True)

# Графік 2: Стовпчикова діаграма
plt.subplot(3, 1, 2)
plt.bar(table_num.index, table_num['2019'], color="g")
plt.title("Народжуванність у 2019 році")
plt.xlabel("Регіони")
plt.ylabel("Показник")
plt.tick_params(axis="x", rotation=90)
plt.grid(axis="y")

# Графік 3: Графік розсіювання
plt.subplot(3, 1, 3)
plt.scatter(table_num.index, table_num['2019'], color="r", marker="x")
plt.title("Народжуванність у 2019 році")
plt.xlabel("Регіони")
plt.ylabel("Показник")
plt.tick_params(axis="x", rotation=90)
plt.grid(True)

# Відображення графіків
plt.tight_layout()
plt.show()
